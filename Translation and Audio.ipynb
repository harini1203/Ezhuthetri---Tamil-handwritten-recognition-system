# %%
# !pip install translate
# !pip install gTTS

# %%
from translate import Translator

def translate_tamil_to_english(tamil_text):
    translator = Translator(to_lang="en", from_lang="ta")
    translation = translator.translate(tamil)
    return translation

if __name__ == "__main__":
    tamil = "அ ஆ ஈ உ ஊ எ ஐ ஒ ஔ "
    translated_text = translate_tamil_to_english(tamil)
    print(f"Tamil: {tamil}")
    print(f"English: {translated_text}")
# Out:
#   File "<ipython-input-8-b9e39cf9d334>", line 9
#     tamil = "அனன்யா சற்று தள்ளி அன்பரசி வ ீட்டிலிருந்து நடந்து வந்திருக்க, அ.ததாழி
#             ^
# SyntaxError: unterminated string literal (detected at line 9)

# %%
 from gtts import gTTS
from IPython.display import Audio, display
import os

# Tamil text you want to convert to audio
tamil_text = tamil
# Create a gTTS object
tts = gTTS(text=tamil_text, lang='ta')

# Get the current working directory
current_directory = os.getcwd()

# Save the audio file in the current working directory
audio_file_path = os.path.join(current_directory, "output_tamil_audio.mp3")
tts.save(audio_file_path)

#print(f"Audio file '{audio_file_path}' generated.")

# Display a play button for the audio
display(Audio(audio_file_path))
# Out:
#   File "<ipython-input-6-682110368c66>", line 4
#     tamil="அனன்யா சற்று தள்ளி அன்பரசி வ ீட்டிலிருந்து நடந்து வந்திருக்க, அ.ததாழி
#           ^
# SyntaxError: unterminated string literal (detected at line 4)
